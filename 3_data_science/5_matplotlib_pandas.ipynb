# %% [markdown]
# # **Tracciare Grafici con Matplotlib Pyplot e Pandas**
# In questo notebook esploreremo come utilizzare **Matplotlib Pyplot** e **Pandas** per visualizzare dati in diversi tipi di grafici.

# %%
# %pip install matplotlib pandas numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## **1. Grafico a Linee con Pandas**
# Un **grafico a linee** è utile per rappresentare dati continui, come trend nel tempo.

# %%
# Creazione di un DataFrame Pandas
data = {
    "Mese": ["Gen", "Feb", "Mar", "Apr", "Mag", "Giu"],
    "Vendite": [1000, 1200, 1500, 1700, 1600, 1800]
}

df = pd.DataFrame(data)

# Creazione del grafico
plt.figure(figsize=(6, 4))
plt.plot(df["Mese"], df["Vendite"], marker='o', linestyle='-', color='blue', label="Vendite Mensili")

# Etichette e titolo
plt.xlabel("Mese")
plt.ylabel("Vendite (€)")
plt.title("Andamento delle Vendite")
plt.legend()
plt.grid(True)

# Mostra il grafico
plt.show()

# %% [markdown]
# ## **2. Grafico a Barre con Pandas**
# Un **grafico a barre** è utile per confrontare categorie di dati.

# %%
# Creazione di un DataFrame Pandas
data = {
    "Prodotto": ["A", "B", "C", "D"],
    "Vendite": [300, 500, 200, 400]
}

df = pd.DataFrame(data)

# Creazione del grafico
df.plot(kind="bar", x="Prodotto", y="Vendite", color="green", legend=False, figsize=(6, 4))

# Etichette e titolo
plt.xlabel("Prodotto")
plt.ylabel("Vendite (€)")
plt.title("Vendite per Prodotto")

# Mostra il grafico
plt.show()

# %% [markdown]
# ## **3. Grafico a Dispersione con Pandas**
# Un **grafico a dispersione** mostra la relazione tra due variabili.

# %%
# Creazione di un DataFrame casuale
np.random.seed(42)
df = pd.DataFrame({
    "Altezza": np.random.normal(170, 10, 50),
    "Peso": np.random.normal(70, 15, 50)
})

# Creazione del grafico
df.plot(kind="scatter", x="Altezza", y="Peso", color="red", figsize=(6, 4))

# Titolo
plt.title("Relazione tra Altezza e Peso")

# Mostra il grafico
plt.show()

# %% [markdown]
# ## **4. Istogramma con Pandas**
# Un **istogramma** mostra la distribuzione di una variabile numerica.

# %%
# Creazione di un DataFrame con dati casuali
df = pd.DataFrame({"Età": np.random.randint(18, 60, 1000)})

# Creazione dell'istogramma
df["Età"].plot(kind="hist", bins=20, color="purple", edgecolor="black", alpha=0.7, figsize=(6, 4))

# Titolo
plt.title("Distribuzione dell'Età")

# Mostra il grafico
plt.show()

# %% [markdown]
# ## **5. Grafico a Torta con Pandas**
# Un **grafico a torta** rappresenta le proporzioni tra le categorie.

# %%
# Creazione di un DataFrame
data = {
    "Categoria": ["A", "B", "C", "D"],
    "Percentuale": [40, 30, 20, 10]
}

df = pd.DataFrame(data)

# Creazione del grafico a torta
df.set_index("Categoria").plot(kind="pie", y="Percentuale", autopct='%1.1f%%', figsize=(6, 6))

# Titolo
plt.title("Distribuzione Categorie")

# Mostra il grafico
plt.show()

# %% [markdown]
# ## **6. Conclusione**
# Abbiamo esplorato come visualizzare dati con **Matplotlib Pyplot e Pandas**, includendo:
# - **Grafico a linee** 📈
# - **Grafico a barre** 📊
# - **Grafico a dispersione** 🔴
# - **Istogramma** 📊
# - **Grafico a torta** 🥧
#
# Questi strumenti sono fondamentali per analizzare e rappresentare dati in modo efficace! 🚀
